# %%
import matplotlib
from autoviz.AutoViz_Class import AutoViz_Class
import numpy as np
np.set_printoptions(suppress=True)
import joblib as jb
import pandas as pd
# Out:
# c:\Users\waldo\miniforge3\envs\faa\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# Imported v0.1.807. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
df = pd.DataFrame(jb.load('01_EDA_Cleanup.bin'))

# %%
df = df.dropna()

# %%
AV = AutoViz_Class()

# %%
# %matplotlib inline
df = AV.AutoViz(
    filename='',  # Since we are passing the DataFrame, filename is empty
    sep=',',      # Separator in the file, if you are reading in the DataFrame adjust as necessary
    dfte=df,      # Your DataFrame
    #depVar='hospital_death',    # Optional: dependent variable for analyzing its relationship with other variables
    chart_format='svg',  # Format of the visualization output
    verbose=0,
    #save_plot_dir='01_EDA_AutovizOut'
)
# Out:
# Shape of your Data Set loaded: (56935, 31)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# encounter_id of type=Int64 is not classified
# hospital_id of type=Int64 is not classified
# age of type=Int64 is not classified
# bmi of type=Float64 is not classified
# height of type=Float64 is not classified
# icu_id of type=Int64 is not classified
# pre_icu_los_days of type=Float64 is not classified
# weight of type=Float64 is not classified
# apache_2_diagnosis of type=Int64 is not classified
# apache_3j_diagnosis of type=Float64 is not classified
# gcs_eyes_apache of type=Int64 is not classified
# gcs_motor_apache of type=Int64 is not classified
# gcs_verbal_apache of type=Int64 is not classified
# ...

# %%
# %matplotlib inline
df = AV.AutoViz(
    filename='',  # Since we are passing the DataFrame, filename is empty
    sep=',',      # Separator in the file, if you are reading in the DataFrame adjust as necessary
    dfte=df,      # Your DataFrame
    depVar='hospital_death',    # Optional: dependent variable for analyzing its relationship with other variables
    chart_format='svg',  # Format of the visualization output
    verbose=0,
    #save_plot_dir='01_EDA_AutovizOut'
)
# Out:
# Shape of your Data Set loaded: (56935, 31)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# encounter_id of type=Int64 is not classified
# hospital_id of type=Int64 is not classified
# age of type=Int64 is not classified
# bmi of type=Float64 is not classified
# height of type=Float64 is not classified
# icu_id of type=Int64 is not classified
# pre_icu_los_days of type=Float64 is not classified
# weight of type=Float64 is not classified
# apache_2_diagnosis of type=Int64 is not classified
# apache_3j_diagnosis of type=Float64 is not classified
# gcs_eyes_apache of type=Int64 is not classified
# gcs_motor_apache of type=Int64 is not classified
# gcs_verbal_apache of type=Int64 is not classified
# ...

# %% [markdown]
# 1- Crear entorno virtual:
#   **`python -m venv fundamentos/env`**
#
# 2- Para activar el entorno virtual: **`source fundamentos/env/bin/activate`**
#
# 3- Desactivar el entorno: **`deactivate`**
#
# 4- Instalar Jupyter Lab: **`pip install jupyter notebook`**
#
# 5- Iniciar Jupyter lab: **`jupyter lab`**
